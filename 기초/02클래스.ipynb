# %% [markdown]
# <a href="https://colab.research.google.com/github/b-chae/PythonTutoring/blob/main/02%ED%81%B4%EB%9E%98%EC%8A%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 클래스
# - 클래스란 무엇인가?
# - 함수와의 다른점?

# %%
# 함수를 사용하여 덧셈을 하는 계산기 만들기

result = 0

def add(num):
  global result
  result += num
  return result

print(add(3))
print(add(4))
# Out:
# 3
# 7

# %%
# 만약 계산기가 두개가 필요하다면?

result1 = 0
result2 = 0

def add1(num):
  global result1
  result1 += num
  return result1

def add2(num):
  global result2
  result2 += num
  return result2

print(add1(3))
print(add1(4))
print(add2(3))
print(add2(7))
# Out:
# 3
# 7
# 3
# 10

# %%
class Calculator:
  def __init__(self):
    self.result = 0

  def add(self, num):
    self.result += num
    return self.result

cal1 = Calculator()
cal2 = Calculator()

print(cal1.add(3))
print(cal1.add(4))
print(cal2.add(3))
print(cal2.add(7))
# Out:
# 3
# 7
# 3
# 10

# %% [markdown]
# #### 클래스와 객체
# ![Screen Shot 2021-01-02 at 5.59.26 PM.png](data:image/png;base64,...)
# - 과자 틀 : 클래스
# - 과자 틀에 의해서 만들어진 과자
# - 클래스란 똑같은 무엇인가를 계속해서 만들어 낼 수 있는 틀
# - 객체란 클래스를 사용하여 만들어낸 것들,
# - 객체마다 고유한 성격을 가진다
# - 과자1을 베어문다고 해도 과제2, 과자3에 아무 영향이 없다

# %%
# 과자 클래스를 만들어보자
# 과자에 필요한 것들이 무엇이 있을까? (이름, 가격, 색깔, 등등...)

# %%
# 주문을 받을 수 있는 카페 클래스를 만들어보자

class Cafe:
  menu = []

  def __init__(self, name):
    print("안녕하세요, " + name + " 입니다!")

# %% [markdown]
# #### Account 클래스
# - 은행에 가서 계좌를 개설하면 은행이름, 예금주, 계좌번호, 잔액이 설정됩니다.
#
# 1.   생성자 만들기, 은행이름은 SC은행으로 계좌번호는 3자리-2자리-6자리 형태로 랜덤하게 생성됩니다.
# 2.   정보 출력 메서드 만들기, Account 객체에 저장된 정보를 출력하는 display_info() 메서드를 추가하세요.
#
# ```
# 은행이름: SC은행
# 예금주: 파이썬
# 계좌번호: 111-11-111111
# 잔고: 10000원
# ```
# 3. 입금 메서드, 입금을 위한 deposit 메서드를 추가하세요. 입금은 최소 1원 이상만 가능합니다.
# 4. 출금 메서드, 출금을 위한 withdraw 메서드를 추가하세요. 출금은 계좌의 잔고 이상으로 출금할 수 없습니다.
# 5. 이자 지급하기, 입금횟수가 4회가 될 때 잔고의 기준으로 1%의 이자가 잔고에 추가되도록 코드를 변경해보세요.
# 6. 입출금 내역, 입금과 출급 내역이 기록되도록 코드를 업데이트 하세요. 입금 내역과 출금 내역을 출력하는 deposit_history와 withdraw_history 메서드를 추가하세요.

# %%
# Account 클래스

# %% [markdown]
# [문제출처](https://wikidocs.net/7037)
